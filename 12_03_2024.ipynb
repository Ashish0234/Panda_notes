# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\user\Downloads\stock_data.csv',skiprows=1)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet3')

# %%
data
# Out:
#            NAME         DOB GRADE
# 0  ASHISH KUMAR  21\07\1999  PASS
# 1         DIPAK  28\06\1999  FAIL
# 2         ANAND  22\08\1999  FAIL
# 3   ANUBHAV SIR  01\01\1999  PASS

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR          V         23
# 2   ANAND RAJAK         VI         20
# 3    AMAN NAYAK        VII         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx',skiprows=1)

# %%
data
# Out:
#            NAME CLASS  ROLL
# 0  ASHISH KUMAR     V    23
# 1   ANAND RAJAK    VI    20
# 2    AMAN NAYAK   VII    21
# 3  DIPAK PRASAD   VII    19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet2',skiprows=2)

# %%
data
# Out:
#            NAME BLOOD GROUP   CITY
# 0  ASHISH KUMAR         AB+  ASSAM
# 1   ANAND RAJAK          A+     WB
# 2    AMAN NAYAK         AB-  BIHAR

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet3',skiprows=1)

# %%
data
# Out:
#            NAME         DOB GRADE
# 0  ASHISH KUMAR  21\07\1999  PASS
# 1         DIPAK  28\06\1999  FAIL
# 2         ANAND  22\08\1999  FAIL
# 3   ANUBHAV SIR  01\01\1999  PASS

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet3',header=1)

# %%
data
# Out:
#            NAME         DOB GRADE
# 0  ASHISH KUMAR  21\07\1999  PASS
# 1         DIPAK  28\06\1999  FAIL
# 2         ANAND  22\08\1999  FAIL
# 3   ANUBHAV SIR  01\01\1999  PASS

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1',skiprows=1,header=None,names=['Information'])

# %%
data
# Out:
#                    Information
# NAME         CLASS        ROLL
# ASHISH KUMAR V              23
# ANAND RAJAK  VI             20
# AMAN NAYAK   VII            21
# DIPAK PRASAD VII            19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet3',nrows=2)

# %%
data
# Out:
#      Unnamed: 0  Unnamed: 1 Unnamed: 2
# 0          NAME         DOB      GRADE
# 1  ASHISH KUMAR  21\07\1999       PASS

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1',na_values=['n.a.','not available'])

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data.to_csv(r'C:\Users\user\Desktop\ASHISH\Ashish.csv',index=False)

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data.to_csv(r'C:\Users\user\Desktop\ASHISH\AshiSH2.csv',index=False,header=False)

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data.to_csv(r'C:\Users\user\Desktop\ASHISH\AshiSH2.csv',index=False,header=False,columns=['Unnamed: 0'])

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data.to_csv(r'C:\Users\user\Desktop\ASHISH\AshiSH2.csv',mode='a',index=False,header=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 data.to_csv(r'C:\Users\user\Desktop\ASHISH\AshiSH2.csv',mode='a',index=False,header=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
# ...

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1',na_values=['n.a.','not available'])

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1',index_col=False)

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1',header=None, names=['a','b','c'])

# %%
data
# Out:
#               a      b     c
# 0           NaN    NaN   NaN
# 1          NAME  CLASS  ROLL
# 2  ASHISH KUMAR    NaN    23
# 3   ANAND RAJAK     VI   NaN
# 4    AMAN NAYAK    NaN    21
# 5  DIPAK PRASAD    VII    19

# %%
def convert_people(co):
    if co=='ANAND RAJAK':
        return 'CHOTA BABU'
    else:
        return co

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2   ANAND RAJAK         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet1',converters={'Unnamed: 0':convert_people})

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2    CHOTA BABU         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data.to_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE1.xlsx')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2    CHOTA BABU         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data2=pd.read_excel(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE.xlsx','Sheet2',skiprows=2)

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          NAME      CLASS       ROLL
# 1  ASHISH KUMAR        NaN         23
# 2    CHOTA BABU         VI        NaN
# 3    AMAN NAYAK        NaN         21
# 4  DIPAK PRASAD        VII         19

# %%
data2
# Out:
#            NAME BLOOD GROUP   CITY
# 0  ASHISH KUMAR         AB+  ASSAM
# 1   ANAND RAJAK          A+     WB
# 2    AMAN NAYAK         AB-  BIHAR

# %%
with pd.ExcelWriter(r'C:\Users\user\Desktop\ASHISH\ASHISH_EXCEL_FILE3.xlsx') as wr:
    data.to_excel(wr,sheet_name='Sheet1')
    data2.to_excel(wr,sheet_name='Sheet2')

# %%
data2.shape
# Out:
# (3, 3)

# %%
data4=pd.read_csv(r'C:\Users\user\Desktop\ASHISH\stock_data.csv')

# %%
data4
# Out:
#             Date   Open   High    Low  Close    Volume  Name
# 0       1/3/2006  39.69  41.22  38.79  40.91  24232729  AABA
# 1       1/4/2006  41.22  41.90  40.77  40.97  20553479  AABA
# 2       1/5/2006  40.93  41.73  40.85  41.53  12829610  AABA
# 3       1/6/2006  42.88  43.57  42.80  43.21  29422828  AABA
# 4       1/9/2006  43.10  43.66  42.82  43.42  16268338  AABA
# ...          ...    ...    ...    ...    ...       ...   ...
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165  AABA
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802  AABA
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124  AABA
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877  AABA
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 7 columns]

# %%
data4.shape
# Out:
# (3019, 7)

# %%
data4.head(8)
# Out:
#         Date   Open   High    Low  Close    Volume  Name
# 0   1/3/2006  39.69  41.22  38.79  40.91  24232729  AABA
# 1   1/4/2006  41.22  41.90  40.77  40.97  20553479  AABA
# 2   1/5/2006  40.93  41.73  40.85  41.53  12829610  AABA
# 3   1/6/2006  42.88  43.57  42.80  43.21  29422828  AABA
# 4   1/9/2006  43.10  43.66  42.82  43.42  16268338  AABA
# 5  1/10/2006  42.96  43.34  42.34  42.98  16288580  AABA
# 6  1/11/2006  42.19  42.31  41.72  41.87  26192772  AABA
# 7  1/12/2006  41.92  41.99  40.76  40.89  18921686  AABA

# %%
data4.tail(9)
# Out:
#             Date   Open   High    Low  Close    Volume  Name
# 3010  12/18/2017  70.54  70.74  69.95  70.14   6776982  AABA
# 3011  12/19/2017  69.70  70.36  69.38  70.21  14654994  AABA
# 3012  12/20/2017  70.60  71.05  70.17  70.90  12888149  AABA
# 3013  12/21/2017  71.00  72.17  70.88  71.59   9682733  AABA
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165  AABA
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802  AABA
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124  AABA
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877  AABA
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070  AABA
